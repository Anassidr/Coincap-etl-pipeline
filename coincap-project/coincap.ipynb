# %%
import os 
import requests as re
 
import pandas as pd


data = re.get("http://api.coincap.io/v2/assets/bitcoin/history?interval=d1").json()

data
# Out:
# {'data': [{'priceUsd': '44090.9649578312884148',
#    'time': 1646179200000,
#    'date': '2022-03-02T00:00:00.000Z'},
#   {'priceUsd': '43161.6197464701044693',
#    'time': 1646265600000,
#    'date': '2022-03-03T00:00:00.000Z'},
#   {'priceUsd': '40995.7250133253011584',
#    'time': 1646352000000,
#    'date': '2022-03-04T00:00:00.000Z'},
#   {'priceUsd': '39230.6224634563558757',
#    'time': 1646438400000,
#    'date': '2022-03-05T00:00:00.000Z'},
#   {'priceUsd': '39116.7627311843638734',
#    'time': 1646524800000,
#    'date': '2022-03-06T00:00:00.000Z'},
#   {'priceUsd': '38325.5319344115321780',
#    'time': 1646611200000,
#    'date': '2022-03-07T00:00:00.000Z'},
#   {'priceUsd': '38674.9813826424371594',
#    'time': 1646697600000,
#    'date': '2022-03-08T00:00:00.000Z'},
#   {'priceUsd': '41560.7051911425463495',
#    'time': 1646784000000,
#    'date': '2022-03-09T00:00:00.000Z'},
#   {'priceUsd': '39681.3417061066901764',
#    'time': 1646870400000,
# ...
